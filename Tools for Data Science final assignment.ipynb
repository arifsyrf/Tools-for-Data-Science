# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Mohd Arif Asyraf**

# %% [markdown]
# Data Scientist

# %% [markdown]
# *I am interested in data science because, I want to combine the power of AI/ML with the business requirements, to create powerful solutions and provide deep insights into issues an organization needs to solve or discover underlying patterns to discover new potential insights*

# %% [markdown]
# ### The code following is to show the value of "Blue + Red"

# %%
Blue = 50
Red = 20
print(Blue + Red)
# Out:
# 70

# %% [markdown]
# Horizontal rule
# ***
# - Bullet list
#
# 1. Number list
#
# | Table | Table | Table |
# | --- | --- | --- |
# | Table | Table | Table |

# %% [markdown]
# [Google page Hi](https://www.google.com/search?q=hi&rlz=1C1SQJL_enMY853MY853&oq=hi&aqs=chrome..69i57j46i67j35i39l2j0i67l4j46i131i199i433i465i512j0i131i433i512.3005j0j7&sourceid=chrome&ie=UTF-8)
# <a href="https://www.google.com/search?q=hi&rlz=1C1SQJL_enMY853MY853&oq=hi&aqs=chrome..69i57j46i67j35i39l2j0i67l4j46i131i199i433i465i512j0i131i433i512.3005j0j7&sourceid=chrome&ie=UTF-8" target="_blank" rel="noopener noreferrer">Google page Hi new</a>

# %% [markdown]
# ![72fb76d9-d3ad-45a4-9323-e9924a3d7805.jpg](attachment:9781eea6-c5c3-423d-b910-073f602febc8.jpg)

# %% [markdown]
# > Blocked Quotes

# %% [markdown]
# ~~Strikethrough~~

# %% [markdown]
# ```python
# {
#     Blue = 50
#     Red = 20
#     print(Blue + Red)
#     print("code/syntax highlighting examples")
# }
# ```
